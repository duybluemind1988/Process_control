# %% [markdown]
# # Copy from scrip to jupyter

# %%
import streamlit as st
import seaborn as sns; sns.set()
import pandas as pd
import numpy as np

import plotly.graph_objects as go
from plotly.subplots import make_subplots
#import statistics as st
import warnings
warnings.filterwarnings("ignore")
import glob
import sys,os
import xlrd

#-----------------Design_layout main side-----------------#
st.markdown('<style>h1{color: green;}</style>', unsafe_allow_html=True)
st.title('Process quality control')

st.subheader('Created by: DNN')
st.header("Information")

#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 3000 (2019_2020)_2' #OK
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 3000' #OK
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 2600' #OK
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan E series' #OK
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 4000' #OK
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan Mic 6500'
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan Telecoil'
path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan VPU'
text2= st.text_input("1. Please input folder name for data analysis (MUST)",path)
path=text2 +'/'
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Membrane 3000S/'
#st.write('path input: '+path)

st.write('Accept any public folders like copy room or QA folder, currently not allow private folder')
text3=st.text_input("2. Please input folder name for saving (option)",'//Vn01w2k16v18/data/Copyroom/Test_software/Data/Save')
path3=text3+'/'

#-----------------Design_layout left side-----------------#
st.sidebar.title("Help")
#st.sidebar.info("2. Number of Sample: all sample need to be measured each inspection")
st.sidebar.info("1. Folder name: Folder contains all excel file related to specific product")
st.sidebar.info("2. Name file: product name or item config for saving. Ex: Membrane_33AA079")

st.sidebar.title("About author")
st.sidebar.info("if you have questionns, please contact to DNN@sonion.com")
st.sidebar.title("Software")
st.sidebar.info("This web app was written by Python program language (offline mode). Please use\
                this app inside Sonion only")
#---------------sort file by created_time-------------------------# 

#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 3000'
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 2600'
#path='//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan E series'
path=path+'/'
#print(path)
all_files1=glob.glob(path + '*.xlsx')
all_files2=glob.glob(path + '*.xlsm')
all_files=all_files1+all_files2
#sort file in directory by reverse:
all_files = sorted(all_files, reverse = False)
st.text('number of files: '+str(len(all_files)))
st.text(all_files)
all_files
# Out:
# ['//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan VPU\\Control Plan data MIC VPU - WK36 - 2020.xlsm',
#  '//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan VPU\\Control Plan data MIC VPU - WK37 - 2020.xlsm',
#  '//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan VPU\\Control Plan data MIC VPU - WK38 - 2020.xlsm',
#  '//Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan VPU\\Control Plan data MIC VPU - WK39 - 2020.xlsm']

# %%
path_name=all_files[-1] # get latest file
xls = xlrd.open_workbook(path_name, on_demand=True)
sheet_names=xls.sheet_names()
sheet_names
master_sheet_name=sheet_names[0] 
master_sheet=pd.read_excel(xls, master_sheet_name)
master_sheet

# %%
pd.set_option('display.max_columns', None)

# %%
path_name=all_files[0] # week 36-2019
print(path_name)
print(pd.ExcelFile(path_name).sheet_names)
xls = xlrd.open_workbook(path_name, on_demand=True)
name='83620-Diameter'
a=pd.read_excel(xls, name)
a[21:29]
# Out:
# //Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan VPU\Control Plan data MIC VPU - WK36 - 2020.xlsm
# ['Master list', '83620-Diameter', '83735-Burr and Dim', '83712-Push down flap', '83720-Apply gel - Check gel', '83746-Calibrate flap', '83748-Check Golden samples', '83743-Measure flap position', 'Q-Gel Q300 A-B', '83991-Peel force', '83991-Peel force -Surface', '83951-Final Control-Reflow', '83951-Final Control-Tapping', '83951-Final Control-THD,Imp', '83951-83945-FCQ-Test gel', '83951-83945-FCQ-Golden', '83945-83951-FCQ-Leak', '83770-Tension force & Gap', '83780-Tension force & Gap', '83785 - Height Dimension', '83785-Peel force', '83785-Solder balling', '83945-Final control - THD']
#           $P$27     Unnamed: 1                     Unnamed: 2  \
# 21          NaN            NaN                            NaN
# 22         Item            NaN  Min\n(Specific for each line)
# 23  Sample size            NaN                              1
# 24        Freq.  Quantity time                              6
# 25          NaN  Quantity size                             ID
# 26          NaN           Time                              1
# 27          NaN         Period                          Month
# 28          NaN            NaN                            NaN
#
#                 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 21                     NaN        NaN        NaN        NaN        NaN
# 22  Standard for all lines        NaN        NaN        NaN        NaN
# 23                       2          3          5         10         20
# 24                       5          4          3          2          1
# 25                     Lot    Package        NaN        NaN        NaN
# 26                       2          4        NaN        NaN        NaN
# 27                    Week        Day      Shift       Hour        NaN
# 28                     NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 8  \
# 21        NaN
# 22        NaN
# 23         30
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
#
#    Công đoạn/Operation number/name: 83620-Đục lỗ bù - Đo đường kính / 83620-Punch compensation hole - Diameter  \
# 21                                                NaN
# 22                                               Ngày
# 23                                               Date
# 24                                                NaN
# 25                                2020-08-31 10:31:09
# 26                                2020-08-31 10:31:09
# 27                                2020-08-31 10:31:09
# 28                                2020-08-31 10:31:09
#
#    Unnamed: 10 Unnamed: 11     Unnamed: 12 Unnamed: 13  \
# 21         NaN         NaN             NaN         NaN
# 22          Ca         Máy       Loại hàng       Số Lô
# 23       Shift     Machine           Model   ID number
# 24         NaN         NaN             NaN         NaN
# 25           1           2  Assy cover VPU    61876749
# 26           1           2  Assy cover VPU    61876749
# 27           1           2  Assy cover VPU    61876749
# 28           1           2  Assy cover VPU    61876749
#
#                           Unnamed: 14                            Unnamed: 15  \
# 21                                NaN                                     45
# 22  Hạng mục kiểm tra\nChecking items  Đường kính ngang\nHorizontal Diameter
# 23                                Max                                   0.02
# 24                                Min                                  0.017
# 25                                NaN                                  0.017
# 26                                NaN                                  0.018
# 27                                NaN                                  0.018
# 28                                NaN                                  0.019
#
#                           Unnamed: 16      Unnamed: 17 Unnamed: 18
# 21                                 45              NaN         NaN
# 22  Đường kính dọc\nVertical Diameter  Người đo (MSNV)     Ghi chú
# 23                               0.02            OP ID        Note
# 24                              0.017              NaN         NaN
# 25                               0.02           P21218         NaN
# 26                               0.02           P21218         NaN
# 27                               0.02           P21218         NaN
# 28                              0.017           P21218         NaN

# %%
sheet=a
values_col=sheet.iloc[22,:]
values_col.reset_index(drop=True,inplace=True)
#begin_col=values_col[values_col=='Kích thước\nDimension'].index
begin_col=values_col[values_col.str.contains('Dime')==True].index #sửa lại ngày 2/11/2021
begin_col=begin_col+1
#end_col=values_col[values_col=='MSNV'].index
end_col=values_col[values_col.str.contains('MSNV|OP')==True].index
print(values_col)
print(begin_col)
print(end_col)
# Out:
# 0                                      Item
# 1                                       NaN
# 2             Min\n(Specific for each line)
# 3                    Standard for all lines
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                      Ngày
# 10                                       Ca
# 11                                      Máy
# 12                                Loại hàng
# 13                                    Số Lô
# 14        Hạng mục kiểm tra\nChecking items
# 15    Đường kính ngang\nHorizontal Diameter
# 16        Đường kính dọc\nVertical Diameter
# 17                          Người đo (MSNV)
# 18                                  Ghi chú
# Name: 22, dtype: object
# Int64Index([], dtype='int64')
# Int64Index([17], dtype='int64')

# %%
 if (not begin_col.values): print('error')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-40ad6a005524> in <module>
# ----> 1 if (not begin_col.values): print('error')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
path_name=all_files[-1] # week 36-2019
print(path_name)
print(pd.ExcelFile(path_name).sheet_names)
xls = xlrd.open_workbook(path_name, on_demand=True)
name='40310_Winding coil_Dimension '
b=pd.read_excel(xls, name)
b[21:29]
# Out:
# //Vn01w2k16v18/data/Copyroom/Test_software/Data/Control plan/Control plan 4000\Control Plan data REC 4000 - WK43 - 2020.xlsm
# ['Master list', '40310_Winding coil_Dimension ', '40310-40320 Air bubble ', '40430_Laminating Foil ', '40460_Cuting compensation hole ', '40510-40520_Air gap in case ', '40510-40610 Bonding maget ', '40650_Gluing shockplate', '40540_Bonding coil in case ', '40610-40650 Air gap in cover', '40630_Bonding spacer ring ', '40640_Gluing menbrane on cover ', '40740_Apply glue on ARM', '40830_Magnetizing', '40904_ Print on shield plate ', '40906 Combine 2 receivers', '40907-Combine REC & Plate ', '40920_Soldering lead wire ', '40940 Welding spout Dual REC', '40420-Spraying Adhesive ', '40940_Weiding spout _44AG030GW', '40940 Welding spout_single ', '40950 Sealing spout', '40953-Cuting groundstrip H1G', '40953-Cuting groundstrip H2', '40956-Cuting gounndstrip', '40956 Welding cutting GNDstrip', '40961 Place & solder reisistor', '40962 Shielding can H2G', '40962-Shieling can ', '40968 Soldering gold pad', '40948 - Adapter on spout', '40908_Print on Receiver', '40928_Soldering Lead wire', '40970_Coating Lead wire']
#           $P$27     Unnamed: 1                     Unnamed: 2  \
# 21          NaN            NaN                            NaN
# 22         Item            NaN  Min\n(Specific for each line)
# 23  Sample size            NaN                              1
# 24        Freq.  Quantity time                              6
# 25          NaN  Quantity size                             ID
# 26          NaN           Time                              1
# 27          NaN         Period                          Month
# 28          NaN            NaN                            NaN
#
#                 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 21                     NaN        NaN        NaN        NaN         NaN
# 22  Standard for all lines        NaN        NaN        NaN         NaN
# 23                       2          3          5         10        20.0
# 24                       5          4          3          2         1.0
# 25                     Lot    Package        NaN        NaN         NaN
# 26                       2          4        NaN        NaN         NaN
# 27                    Week        Day      Shift       Hour         NaN
# 28                     NaN        NaN        NaN        NaN         NaN
#
#     Unnamed: 8  \
# 21         NaN
# 22         NaN
# 23        30.0
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
#
#    Công đoạn/Operation number/name: 40310 - Quấn dây/ 40310-Winding coil  \
# 21                                                NaN
# 22                                               Ngày
# 23                                               Date
# 24                                                NaN
# 25                                2020-10-16 14:55:32
# 26                                2020-10-16 14:56:22
# 27                                2020-10-16 14:57:19
# 28                                2020-10-16 14:57:58
#
#    Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13            Unnamed: 14  \
# 21         NaN         NaN         NaN         NaN                    NaN
# 22          Ca   Loại hàng       Số PO        Máy   Kích thước\nDimension
# 23       Shift       Model  Series No.     Machine                    Max
# 24         NaN         NaN         NaN         NaN                    Min
# 25           2     COIL 20         NaN           1                    NaN
# 26           2     COIL 20         NaN           1                    NaN
# 27           2     COIL 20         NaN           1                    NaN
# 28           2     COIL 20         NaN           2                    NaN
#
#    Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 21         621         579         579         561        1929         NaN
# 22       Dim G       Dim E       Dim I       Dim D       Dim C        MSNV
# 23         NaN        0.63         NaN        2.15        1.44       Op ID
# 24        0.18         NaN        1.65         NaN         NaN         NaN
# 25       0.217       0.564       1.677       1.993       1.376        5568
# 26       0.207       0.566       1.682       1.983        1.38        5568
# 27       0.206       0.558       1.677       1.989        1.37        5568
# 28       0.213       0.569       1.691       1.994       1.381        5568
#
#    Unnamed: 21
# 21         NaN
# 22     Ghi chú
# 23       Notes
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN

# %%
sheet=b
values_col=sheet.iloc[22,:]
values_col.reset_index(drop=True,inplace=True)
#begin_col=values_col[values_col=='Kích thước\nDimension'].index
begin_col=values_col[values_col.str.contains('Dime')==True].index #sửa lại ngày 2/11/2021
begin_col=begin_col+1
#end_col=values_col[values_col=='MSNV'].index
end_col=values_col[values_col.str.contains('MSNV|OP')==True].index
print(values_col)
print(begin_col)
print(end_col)
# Out:
# 0                              Item
# 1                               NaN
# 2     Min\n(Specific for each line)
# 3            Standard for all lines
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                              Ngày
# 10                               Ca
# 11                        Loại hàng
# 12                            Số PO
# 13                             Máy
# 14            Kích thước\nDimension
# 15                            Dim G
# 16                            Dim E
# 17                            Dim I
# 18                            Dim D
# 19                            Dim C
# 20                             MSNV
# 21                          Ghi chú
# Name: 22, dtype: object
# Int64Index([15], dtype='int64')
# Int64Index([20], dtype='int64')

# %%
#---------------process data-------------------------# 
#@st.cache(suppress_st_warning=True,allow_output_mutation=True)

all_process_week={}
for path_name in all_files: # read each excel file
  week_name=path_name[-16:-5]
  print(week_name,'-'*20)
  xls = xlrd.open_workbook(path_name, on_demand=True)
  sheet_names=xls.sheet_names()
  #print(xls.sheet_names())
  sheet_dict={}
  xls = pd.ExcelFile(path_name) 
  for name in sheet_names: # read each sheet in excel file
    sheet_dict[name] = pd.read_excel(xls, name)
    #sheet_dict[name].to_excel(name+'.xlsx')
  #break
  # Read all process in one week
  sheet_all={} # most important (reset sheet_all to empty)
  sheet_error=[]
  for name_sheet in sheet_names[1:]: # read each sheet name (process)
    #if name_sheet!='39682': continue # debug each name sheet
    print(name_sheet)
    sheet=sheet_dict[name_sheet]

    # find begin and end col
    values_col=sheet.iloc[22,:]
    values_col.reset_index(drop=True,inplace=True)  # Date, MSVN, DIM A,B,C....
    #print(values_col)
    #if values_col.str.contains('Check')==True:
    #    begin_col=values_col[values_col.str.contains('Check')==True]
    begin_col=values_col[values_col.str.contains('Dime')==True].index #sửa lại ngày 2/11/2021, begin col la col bat dau lay du lieu
    begin_col=begin_col+1
    end_col=values_col[values_col.str.contains('MSNV|OP')==True].index # end coil la col dung lai sau khi ket thuc lay du lieu
    print(begin_col,end_col)
    #if (not begin_col.values or not end_col.values):continue
    if (not begin_col.values):continue # Nếu không có giá trị (ví dụ như đo khối lương, ko phải dime) thì bỏ quan
    #print(begin_col,end_col)
    #print(begin_col[0])

    df_dict={} # add all value, USL, LSL, UCL... in each process sheet
    #try:
    for name in sheet.columns[begin_col[0]:end_col[-1]]: # all dim in each process (dim a, b, c,d ....)
      dim_name=sheet[name][22]
      #print(dim_name)
      df=pd.DataFrame()
      df_dict[dim_name]={}  

      #tolerance_dict[sheet[name][22]]=[sheet[name][24],sheet[name][23]]  
      try:  
          df['Hour']=sheet[sheet.columns[9]][25:]
          #print('df Date-------------')
          #print(df['Date'])
          # convert hour  
          df['Hour']=df['Hour'].apply(lambda x: x.strftime("%Y %m %d %H")) # group theo hour, gần như trùng với tần suất lấy mẫu đo control plan
          df['Hour']=pd.to_datetime(df['Hour'])
      except:
        continue
      
      df['Value']=sheet[name][25:]
      #print('df Value-------------')
      #print(df['Value'])
      #if np.std(df.Value) == 0: # chuyển qua dim khac nếu các giá trị là giống nhau
      #  continue
      #print('susessful')
      if isinstance(sheet[name][23],str): continue #check string USL
      if isinstance(sheet[name][23],str): continue #check string LSL      
      df['USL']=sheet[name][23] # max
      df['LSL']=sheet[name][24] # min
      #print(df['USL'],df['LSL'])  
      df.dropna(subset=['Value'],inplace=True)
      df=df[pd.to_numeric(df['Value'], errors='coerce').notnull()] # loai bo tat ca not numeric value truoc khi convert
      #df=df[df.columns[1:]].apply(pd.to_numeric, errors='coerce').dropna() # loai bo tat ca not numeric value truoc khi convert
      df[df.columns[1:]]=df[df.columns[1:]].astype('float32')

      #print('df--------------')
      #print(df)    
      #print('final df dict-------')
      #print(dim_name)
      df_dict[dim_name]=df.reset_index(drop=True)  
      #print(df_dict)
    #except Exception as e:
        #exc_type, exc_obj, exc_tb = sys.exc_info()
        #fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        #sheet_error.append(name_sheet)
        #continue
    sheet_all[name_sheet]=df_dict # add each process name to shee_all dict each week
    #print('all process and dim each week-----------------------')
    #print(sheet_all)
    #sheet_all chi chứa name_sheet (process), khong chứa dim name nếu như không có dữ liệu, lưu ý thông tin này khi concat dữ liệu dưới đây
  all_process_week[week_name]=sheet_all
  print(week_name,sheet_error)


all_process_week2=all_process_week # Run function above
# Out:
# WK36 - 2020 --------------------
# 83620-Diameter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-1353fe68eea2> in <module>
#      28     #print(values_col)
#      29     #begin_col=values_col[values_col=='Kích thước\nDimension'].index
# ---> 30     if values_col.str.contains('Check')==True:
#      31         begin_col=values_col[values_col.str.contains('Check')==True]
#      32     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
list(all_process_week2.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-90cabc8a9560> in <module>
# ----> 1 list(all_process_week2.keys())
#
# NameError: name 'all_process_week2' is not defined

# %%
all_process_week2['WK35 - 2019'].keys()
# Out:
# dict_keys(['39682', '38682', '30682', '37682', '30665', '30660-37660-38660', '30380-37380-38380', '37670-39670', '37662', '30650-37650 (3500T)', '37650-38655-39650', '37641', '30470-37470', '38546', '39615', '38940', '38594', '37560', '30740', '37640-38635', '30710-37710-38710', '30674-37674-38674 ', '30672-37672-38672', '30592', '30544-37544-38544-39544', '30538', '30530-37530-39530', '30480-37480-38481', '30370-37370-38370 ', '30750-30940-39750 _S1', '30750-30940-39750 _S2', '37750-37940_S1', '37750-37940_S2'])

# %%
all_process_week2['WK38 - 2020'].keys()
# Out:
# dict_keys(['39682', '38682', '30682', '37682', '30665', '30660-37660-38660', '30380-37380-38380', '37670-39670', '37662', '30650-37650 (3500T)', '37650-38655-39650', '37641', '30470-37470', '38546', '39615', '38940', '38594', '37560', '30740', '37640-38635', '30674-37674-38674 ', '30672-37672-38672', '30592', '30544-37544-38544-39544', '30538', '30530-37530-39530', '30480-37480-38481', '30370-37370-38370 ', '30750-30940-39750 _S1', '30750-30940-39750 _S2', '37750-37940_S1', '37750-37940_S2', '37751', '37312-38312'])

# %%
all_process_week2['WK38 - 2020']['37650-38655-39650'].keys()
# Out:
# dict_keys(['37650 Dim E', '37650 Dim G', '37650 Offset membrane', '38655 Dim E', '38655 Dim G', '38655 Offset membrane', '39650  Dim A', '39650 Dim E', '39650 Dim H', '39650 Offset membrane'])

# %%
all_process_week2['WK36 - 2019']['37650-38655-39650'].keys()
# Out:
# dict_keys(['37650 Dim E', '37650 Dim G', '37650 Offset membrane', '38655 Dim E', '38655 Dim G', '38655 Offset membrane', '39650  Dim A', '39650 Dim E', '39650 Dim H', '39650 Offset membrane'])

# %%
all_process_week2['WK35 - 2019']['39682']

# %%
all_process_week2['WK35 - 2020']['39682']

# %%
all_process_week2['WK38 - 2020']['39682']
# Out:
# {'Chiều rộng Dim E': {},
#  'Chiều dài Dim C': {},
#  'Cung hint Dim I': {},
#  'Cung J Dim J': {},
#  'Offset Dim M': {}}

# %%
#-----------Concat all week to one base week-------------------------#
import copy
#@st.cache(suppress_st_warning=True,allow_output_mutation=True)
def concat_baseweek(all_process_week):
    base_week={}
    base_week=copy.deepcopy(all_process_week[list(all_process_week.keys())[-1]]) # must have copy()
    #print(len(base_week))
    # concat all process in each weeks based on keys value:
    for week_name in list(all_process_week.keys())[:-1]: # ko tính base week nên trừ 1: 
      print(week_name,'-'*20)  
      other_week=all_process_week[week_name]
      for process_name in other_week.keys(): # dict all process
        #if process_name!='39682': continue # for debug only
        #print(process_name)
        for process_name_base in base_week.keys(): # dict all process
            if process_name_base==process_name: # Neu process name trung voi base week thi concat
              #print('Thuc hien lenh concat')  
              for dim_name in base_week[process_name_base].keys(): # concat dim trong process base week voi cac week khac nhau
                 if len(base_week[process_name_base][dim_name]) == 0:
                     base_week[process_name_base][dim_name] = pd.DataFrame.from_dict(base_week[process_name_base][dim_name])
                 if len(other_week[process_name_base][dim_name]) == 0:
                    other_week[process_name_base][dim_name] = pd.DataFrame.from_dict(other_week[process_name_base][dim_name])
                 #print(dim_name)
                 #print('1. base week dim name value: ')
                 #print(a)
                 #print(type(a))
                 #print('2. other week dim name value: ')
                 #print(b)
                 #print(type(b))
                 #try:  
                     #base_week[process_name_base][dim_name]=pd.concat([base_week[process_name_base][dim_name],other_week[process_name_base][dim_name]])
                 base_week[process_name_base][dim_name]=base_week[process_name_base][dim_name].append(other_week[process_name_base][dim_name]) # include empty dataframe
                 #print('3. a------------')
                 #print(a)
                 #except:continue
    #return base_week # for debug only    
    #end here     # for debug only
    #print('Check len all dim in base week for remove zero dim and zero process')
    process_name_list=[]
    dim_name_list=[]
    dim_len_list=[]
    for process_name in base_week.keys(): # all process 
      #print(process_name)
      for dim_name in base_week[process_name].keys(): # all dim in each process
        dim_len=len(base_week[process_name][dim_name])
        #print(dim_name)
        #print(dim_len)
        process_name_list.append(process_name)
        dim_name_list.append(dim_name)
        dim_len_list.append(dim_len)
    dim_and_len_df =pd.DataFrame(list(zip(process_name_list,dim_name_list,dim_len_list)),
                             columns=['Process_Name','Dim_name','Len'])
    dim_and_len_df.sort_values(by='Len')
    # Remove all dim with len = 0
    #print('---------All remove process with dim len = 0---------')
    for i in range(len(dim_and_len_df)):
      if dim_and_len_df.loc[i].Len==0:
        Process_Name=dim_and_len_df.loc[i].Process_Name
        Dim_name=dim_and_len_df.loc[i].Dim_name
        #print(Process_Name,Dim_name)
        base_week[Process_Name].pop(Dim_name,None)
    # Remove all process with no dim:
    all_base_week_process_list=list(base_week.keys())
    for process_name in all_base_week_process_list:
      if len(base_week[process_name]) == 0 :
        base_week.pop(process_name,None)
    return base_week

final_data=concat_baseweek(all_process_week2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-564c55c8d46a> in <module>
#      67     return base_week
#      68
# ---> 69 final_data=concat_baseweek(all_process_week2)
#
# NameError: name 'all_process_week2' is not defined

# %% [markdown]
# # Change name for dict python

# %%
process_name=master_sheet.loc[Master_sheet['Unnamed: 1'] == "39682"]["Unnamed: 4"].values[0]
process_name

# %%
final_data_copy=copy.deepcopy(final_data)
final_data_copy.keys()

# %%
all_sheet_name=final_data_copy.keys()
for name_sheet in all_sheet_name:
    print(name_sheet)
    try:
        process_name=master_sheet.loc[master_sheet['Unnamed: 1'] == name_sheet]["Unnamed: 4"].values[0]
    except:
        process_name=name_sheet
    print(process_name)
    if newkey!=oldkey:  
        final_data_copy[process_name] = final_data_copy[name_sheet]
        del final_data_copy[name_sheet]

# %%
a=final_data['39682']['Chiều rộng Dim E']
a.head()
# Out:
#                  Hour  Value   USL  LSL
# 0 2020-09-07 09:00:00  3.719  3.72  3.7
# 1 2020-09-07 09:00:00  3.720  3.72  3.7
# 2 2020-09-07 09:00:00  3.717  3.72  3.7
# 3 2020-09-08 20:00:00  3.708  3.72  3.7
# 4 2020-09-08 20:00:00  3.713  3.72  3.7

# %%
a.Hour
# Out:
# 0    2020-09-07 09:00:00
# 1    2020-09-07 09:00:00
# 2    2020-09-07 09:00:00
# 3    2020-09-08 20:00:00
# 4    2020-09-08 20:00:00
# 5    2020-09-08 20:00:00
# 0    2020-08-20 09:00:00
# 1    2020-08-20 09:00:00
# 2    2020-08-20 09:00:00
# 0    2020-08-22 17:00:00
# 1    2020-08-22 17:00:00
# 2    2020-08-22 17:00:00
# 3    2020-08-24 12:00:00
# 4    2020-08-24 12:00:00
# 5    2020-08-24 12:00:00
# 6    2020-08-24 18:00:00
# 7    2020-08-24 18:00:00
# 8    2020-08-24 18:00:00
# 9    2020-08-27 08:00:00
# 10   2020-08-27 08:00:00
# 11   2020-08-27 08:00:00
# 0    2020-08-28 17:00:00
# 1    2020-08-28 17:00:00
# 2    2020-08-28 17:00:00
# 3    2020-08-29 12:00:00
# 4    2020-08-29 12:00:00
# 5    2020-08-29 12:00:00
# 6    2020-08-31 16:00:00
# 7    2020-08-31 16:00:00
# 8    2020-08-31 16:00:00
# Name: Hour, dtype: datetime64[ns]

# %%
a['Hour'].apply(lambda x: x.strftime("%Y %m %U"))
# Out:
# 0     2020 09 36
# 1     2020 09 36
# 2     2020 09 36
# 3     2020 09 36
# 4     2020 09 36
# 5     2020 09 36
# 0     2020 08 33
# 1     2020 08 33
# 2     2020 08 33
# 0     2020 08 33
# 1     2020 08 33
# 2     2020 08 33
# 3     2020 08 34
# 4     2020 08 34
# 5     2020 08 34
# 6     2020 08 34
# 7     2020 08 34
# 8     2020 08 34
# 9     2020 08 34
# 10    2020 08 34
# 11    2020 08 34
# 0     2020 08 34
# 1     2020 08 34
# 2     2020 08 34
# 3     2020 08 34
# 4     2020 08 34
# 5     2020 08 34
# 6     2020 08 35
# 7     2020 08 35
# 8     2020 08 35
# Name: Hour, dtype: object

# %%
a['Week']=a['Hour'].apply(lambda x: x.strftime("%Y %m %U"))
#a['Week']=pd.to_datetime(a['Week'])
#cols = a.columns.tolist()
#cols = cols[-1:] + cols[:-1]
#a=a[cols]
a.head()
# Out:
#                  Hour  Value   USL  LSL        Week
# 0 2020-09-07 09:00:00  3.719  3.72  3.7  2020 09 36
# 1 2020-09-07 09:00:00  3.720  3.72  3.7  2020 09 36
# 2 2020-09-07 09:00:00  3.717  3.72  3.7  2020 09 36
# 3 2020-09-08 20:00:00  3.708  3.72  3.7  2020 09 36
# 4 2020-09-08 20:00:00  3.713  3.72  3.7  2020 09 36

# %%
a['Hour'].dt.strftime('%Y-%U')
# Out:
# 0     2020-36
# 1     2020-36
# 2     2020-36
# 3     2020-36
# 4     2020-36
# 5     2020-36
# 0     2020-33
# 1     2020-33
# 2     2020-33
# 0     2020-33
# 1     2020-33
# 2     2020-33
# 3     2020-34
# 4     2020-34
# 5     2020-34
# 6     2020-34
# 7     2020-34
# 8     2020-34
# 9     2020-34
# 10    2020-34
# 11    2020-34
# 0     2020-34
# 1     2020-34
# 2     2020-34
# 3     2020-34
# 4     2020-34
# 5     2020-34
# 6     2020-35
# 7     2020-35
# 8     2020-35
# Name: Hour, dtype: object

# %%
date_trial=final_data['39682']['Chiều rộng Dim E']['Date']
date_trial
# Out:
# 0    2020-09-07 09:00:00
# 1    2020-09-07 09:00:00
# 2    2020-09-07 09:00:00
# 3    2020-09-08 20:00:00
# 4    2020-09-08 20:00:00
# 5    2020-09-08 20:00:00
# 0    2020-08-20 09:00:00
# 1    2020-08-20 09:00:00
# 2    2020-08-20 09:00:00
# 0    2020-08-22 17:00:00
# 1    2020-08-22 17:00:00
# 2    2020-08-22 17:00:00
# 3    2020-08-24 12:00:00
# 4    2020-08-24 12:00:00
# 5    2020-08-24 12:00:00
# 6    2020-08-24 18:00:00
# 7    2020-08-24 18:00:00
# 8    2020-08-24 18:00:00
# 9    2020-08-27 08:00:00
# 10   2020-08-27 08:00:00
# 11   2020-08-27 08:00:00
# 0    2020-08-28 17:00:00
# 1    2020-08-28 17:00:00
# 2    2020-08-28 17:00:00
# 3    2020-08-29 12:00:00
# 4    2020-08-29 12:00:00
# 5    2020-08-29 12:00:00
# 6    2020-08-31 16:00:00
# 7    2020-08-31 16:00:00
# 8    2020-08-31 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
date_trial
# Out:
# 0      7
# 1      7
# 2      7
# 3      8
# 4      8
# 5      8
# 0     20
# 1     20
# 2     20
# 0     22
# 1     22
# 2     22
# 3     24
# 4     24
# 5     24
# 6     24
# 7     24
# 8     24
# 9     27
# 10    27
# 11    27
# 0     28
# 1     28
# 2     28
# 3     29
# 4     29
# 5     29
# 6     31
# 7     31
# 8     31
# Name: Date, dtype: int64

# %%
def configure_plotly_browser_state():
    import IPython
    display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
configure_plotly_browser_state()
process_select=['38682']
#@st.cache(suppress_st_warning=True,allow_output_mutation=True)
def box_chart(process_select):
    fig_all=[]
    for process_name in process_select:
      df_dict=final_data[process_name] # process name
      i=1
      #Layout
      fig = make_subplots(          # Dim name
          rows=len(df_dict), cols=1,
          #shared_xaxes=True, # share same axis
          #vertical_spacing=0.05, # adjust spacing between charts
          #column_widths=[0.8, 0.2],
          subplot_titles=list(df_dict.keys()) # dict with key is process name and value is list of dim (contain name, cp, cpk...)
      )
      for name in list(df_dict.keys()): #also group
        df=df_dict[name].copy()
        df=df.sort_values(by=['Hour'])
        for a in df.columns[1:]:
          df[a] = df[a].round(decimals=3)
        df=df.reset_index(drop=True)
        # Draw control chart
        df_group=df
        df_group=df_group.set_index('Hour')
        #df=df.set_index('Date')
        #if start_date != '':
        #  df=df[start_date:end_date]
        #Control chart 1 
        fig.append_trace(go.Box(
                                x=df_group.index, y=df_group['Value'],name='value ', 
                                line=dict( color='#4280F5'),boxpoints='all'
                                ),row=i, col=1)
        #USL, LSL
        fig.append_trace(go.Scatter(x=df_group.index, y=df_group['USL'],name='USL ', line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
        fig.append_trace(go.Scatter(x=df_group.index, y=df_group['LSL'],name='LSL ',line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
        #fig.append_trace(go.Scatter(x=df['Datef'], y=df['Nominal'],name='Nominal '+name,line=dict( color='#FF5733')),row=i, col=1)
        # UCL, LCL
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['UCL'],name='UCL ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['LCL'],name='LCL ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['Mean'],name='Mean ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
        i=i+1

      if len(df_dict)>1:
        fig.update_layout(height=200*len(df_dict), width=1200, title_text='Process: '+process_name)
      else:
        fig.update_layout(height=300, width=1200, title_text='Process: '+process_name)
      #fig update each process (contain a lot of dim inside)
      #fig.show()
      fig_all.append(fig)  
    return fig_all # fig nay chi la 1 process cuoi cung thoi, lam sao return toan bo fig ?

fig_all_2=box_chart(process_select)    
for fig in fig_all_2:
    fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="877e5b37-80ec-4c70-8032-dc5662cb05af" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("877e5b37-80ec-4c70-8032-dc5662cb05af")) {
#                     Plotly.newPlot(
#                         '877e5b37-80ec-4c70-8032-dc5662cb05af',
#                         [{"boxpoints": "all", "line": {"color": "#4280F5"}, "name": "value ", "type": "box", "x": ["2020-08-14T17:00:00", "2020-08-14T17:00:00", "2020-08-14T17:00:00", "2020-08-14T17:00:00", "2020-08-14T17:00:00", "2020-08-15T08:00:00", "2020-08-15T08:00:00", "2020-08-15T08:00:00", "2020-08-15T08:00:00", "2020-08-15T08:00:00", "2020-08-15T16:00:00", "2020-08-15T16:00:00", "2020-08-15T16:00:00", "2020-08-15T16:00:00", "2020-08-15T16:00:00", "2020-08-17T09:00:00", "2020-08-17T09:00:00", "2020-08-17T09:00:00", "2020-08-17T09:00:00", "2020-08-17T09:00:00", "2020-08-17T17:00:00", "2020-08-17T17:00:00", "2020-08-17T17:00:00", "2020-08-17T17:00:00", "2020-08-17T17:00:00", "2020-08-20T09:00:00", "2020-08-20T09:00:00", "2020-08-20T09:00:00", "2020-08-20T09:00:00", "2020-08-20T09:00:00", "2020-08-20T16:00:00", "2020-08-20T16:00:00", "2020-08-20T16:00:00", "2020-08-20T16:00:00", "2020-08-20T16:00:00", "2020-08-21T16:00:00", "2020-08-21T16:00:00", "2020-08-21T16:00:00", "2020-08-21T16:00:00", "2020-08-21T16:00:00", "2020-08-22T08:00:00", "2020-08-22T08:00:00", "2020-08-22T08:00:00", "2020-08-22T08:00:00", "2020-08-22T08:00:00", "2020-08-22T17:00:00", "2020-08-22T17:00:00", "2020-08-22T17:00:00", "2020-08-22T17:00:00", "2020-08-22T17:00:00", "2020-08-24T12:00:00", "2020-08-24T12:00:00", "2020-08-24T12:00:00", "2020-08-24T12:00:00", "2020-08-24T12:00:00", "2020-08-25T17:00:00", "2020-08-25T17:00:00", "2020-08-25T17:00:00", "2020-08-25T17:00:00", "2020-08-25T17:00:00", "2020-08-26T09:00:00", "2020-08-26T09:00:00", "2020-08-26T09:00:00", "2020-08-26T09:00:00", "2020-08-26T09:00:00", "2020-08-26T16:00:00", "2020-08-26T16:00:00", "2020-08-26T16:00:00", "2020-08-26T16:00:00", "2020-08-26T16:00:00", "2020-08-27T08:00:00", "2020-08-27T08:00:00", "2020-08-27T08:00:00", "2020-08-27T08:00:00", "2020-08-27T08:00:00", "2020-08-27T19:00:00", "2020-08-27T19:00:00", "2020-08-27T19:00:00", "2020-08-27T19:00:00", "2020-08-27T19:00:00", "2020-08-28T10:00:00", "2020-08-28T10:00:00", "2020-08-28T10:00:00", "2020-08-28T16:00:00", "2020-08-28T16:00:00", "2020-08-28T16:00:00", "2020-08-29T12:00:00", "2020-08-29T12:00:00", "2020-08-29T12:00:00", "2020-08-29T15:00:00", "2020-08-29T15:00:00", "2020-08-29T15:00:00", "2020-08-31T08:00:00", "2020-08-31T08:00:00", "2020-08-31T08:00:00", "2020-08-31T16:00:00", "2020-08-31T16:00:00", "2020-08-31T16:00:00", "2020-09-01T16:00:00", "2020-09-01T16:00:00", "2020-09-01T16:00:00", "2020-09-03T08:00:00", "2020-09-03T08:00:00", "2020-09-03T08:00:00", "2020-09-03T17:00:00", "2020-09-03T17:00:00", "2020-09-03T17:00:00", "2020-09-04T09:00:00", "2020-09-04T09:00:00", "2020-09-04T09:00:00", "2020-09-04T16:00:00", "2020-09-04T16:00:00", "2020-09-04T16:00:00", "2020-09-05T08:00:00", "2020-09-05T08:00:00", "2020-09-05T08:00:00", "2020-09-07T09:00:00", "2020-09-07T09:00:00", "2020-09-07T09:00:00", "2020-09-08T10:00:00", "2020-09-08T10:00:00", "2020-09-08T10:00:00", "2020-09-08T16:00:00", "2020-09-08T16:00:00", "2020-09-08T16:00:00"], "xaxis": "x", "y": [0.23800000548362732, 0.23600000143051147, 0.23800000548362732, 0.23800000548362732, 0.23899999260902405, 0.23800000548362732, 0.24699999392032623, 0.24799999594688416, 0.24199999868869781, 0.24699999392032623, 0.24199999868869781, 0.24500000476837158, 0.23999999463558197, 0.24799999594688416, 0.24400000274181366, 0.24500000476837158, 0.24699999392032623, 0.2460000067949295, 0.23999999463558197, 0.24699999392032623, 0.23600000143051147, 0.23899999260902405, 0.23499999940395355, 0.24899999797344208, 0.2290000021457672, 0.23999999463558197, 0.23999999463558197, 0.24300000071525574, 0.23999999463558197, 0.24199999868869781, 0.24300000071525574, 0.23999999463558197, 0.2460000067949295, 0.23999999463558197, 0.24799999594688416, 0.24300000071525574, 0.23600000143051147, 0.2329999953508377, 0.24400000274181366, 0.24199999868869781, 0.23800000548362732, 0.24300000071525574, 0.24300000071525574, 0.23999999463558197, 0.23399999737739563, 0.23999999463558197, 0.23999999463558197, 0.2469 ...

# %%
configure_plotly_browser_state()
process_select=['39682']
#@st.cache(suppress_st_warning=True,allow_output_mutation=True)
#def box_chart_2(process_select):
fig_all=[]
for process_name in process_select:
  df_dict=final_data[process_name] # process name
  i=1
  #Layout
  fig = make_subplots(          # Dim name
      rows=len(df_dict), cols=1,
      #shared_xaxes=True, # share same axis
      #vertical_spacing=0.05, # adjust spacing between charts
      #column_widths=[0.8, 0.2],
      subplot_titles=list(df_dict.keys()) # dict with key is process name and value is list of dim (contain name, cp, cpk...)
  )
  for name in list(df_dict.keys()): #also group
    df=df_dict[name].copy()
    df=df.sort_values(by=['Hour'])
    df['Day']=df['Hour'].apply(lambda x: x.strftime("%Y %m %d"))
    df['Day']=pd.to_datetime(df['Day'])
    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    df=df[cols]
    for a in df.columns[2:]:
      df[a] = df[a].round(decimals=3)
    df=df.reset_index(drop=True)
    # Draw control chart
    df_group=df
    df_group=df_group.set_index('Day')
    #df=df.set_index('Date')
    #if start_date != '':
    #  df=df[start_date:end_date]
    #Control chart 1 
    fig.append_trace(go.Box(
                            x=df_group.index, y=df_group['Value'],name='value ', 
                            line=dict( color='#4280F5'),boxpoints='all'
                            ),row=i, col=1)
    #USL, LSL
    fig.append_trace(go.Scatter(x=df_group.index, y=df_group['USL'],name='USL ', line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
    fig.append_trace(go.Scatter(x=df_group.index, y=df_group['LSL'],name='LSL ',line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
    #fig.append_trace(go.Scatter(x=df['Datef'], y=df['Nominal'],name='Nominal '+name,line=dict( color='#FF5733')),row=i, col=1)
    # UCL, LCL
    #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['UCL'],name='UCL ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
    #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['LCL'],name='LCL ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
    #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['Mean'],name='Mean ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
    i=i+1

  if len(df_dict)>1:
    fig.update_layout(height=200*len(df_dict), width=1200, title_text='Process: '+process_name)
  else:
    fig.update_layout(height=300, width=1200, title_text='Process: '+process_name)
  #fig update each process (contain a lot of dim inside)
  #fig.show()
  fig_all.append(fig)  
#return fig_all # fig nay chi la 1 process cuoi cung thoi, lam sao return toan bo fig ?

#fig_all_2=box_chart_2(process_select)    
for fig in fig_all:
    fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="3de08390-6117-4c95-8330-d221f1d91594" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3de08390-6117-4c95-8330-d221f1d91594")) {
#                     Plotly.newPlot(
#                         '3de08390-6117-4c95-8330-d221f1d91594',
#                         [{"boxpoints": "all", "line": {"color": "#4280F5"}, "name": "value ", "type": "box", "x": ["2020-08-20T00:00:00", "2020-08-20T00:00:00", "2020-08-20T00:00:00", "2020-08-22T00:00:00", "2020-08-22T00:00:00", "2020-08-22T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-27T00:00:00", "2020-08-27T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-28T00:00:00", "2020-08-28T00:00:00", "2020-08-29T00:00:00", "2020-08-29T00:00:00", "2020-08-29T00:00:00", "2020-08-31T00:00:00", "2020-08-31T00:00:00", "2020-08-31T00:00:00", "2020-09-07T00:00:00", "2020-09-07T00:00:00", "2020-09-07T00:00:00", "2020-09-08T00:00:00", "2020-09-08T00:00:00", "2020-09-08T00:00:00"], "xaxis": "x", "y": [3.7190001010894775, 3.7200000286102295, 3.7130000591278076, 3.7200000286102295, 3.7200000286102295, 3.7109999656677246, 3.7119998931884766, 3.7200000286102295, 3.7160000801086426, 3.7070000171661377, 3.7070000171661377, 3.703000068664551, 3.7190001010894775, 3.7200000286102295, 3.7200000286102295, 3.7139999866485596, 3.7049999237060547, 3.7049999237060547, 3.7179999351501465, 3.7100000381469727, 3.7079999446868896, 3.7179999351501465, 3.7119998931884766, 3.7079999446868896, 3.7170000076293945, 3.7200000286102295, 3.7190001010894775, 3.7100000381469727, 3.7130000591278076, 3.7079999446868896], "yaxis": "y"}, {"line": {"color": "#FF5733"}, "mode": "lines", "name": "USL ", "type": "scatter", "x": ["2020-08-20T00:00:00", "2020-08-20T00:00:00", "2020-08-20T00:00:00", "2020-08-22T00:00:00", "2020-08-22T00:00:00", "2020-08-22T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-27T00:00:00", "2020-08-27T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-28T00:00:00", "2020-08-28T00:00:00", "2020-08-29T00:00:00", "2020-08-29T00:00:00", "2020-08-29T00:00:00", "2020-08-31T00:00:00", "2020-08-31T00:00:00", "2020-08-31T00:00:00", "2020-09-07T00:00:00", "2020-09-07T00:00:00", "2020-09-07T00:00:00", "2020-09-08T00:00:00", "2020-09-08T00:00:00", "2020-09-08T00:00:00"], "xaxis": "x", "y": [3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295, 3.7200000286102295], "yaxis": "y"}, {"line": {"color": "#FF5733"}, "mode": "lines", "name": "LSL ", "type": "scatter", "x": ["2020-08-20T00:00:00", "2020-08-20T00:00:00", "2020-08-20T00:00:00", "2020-08-22T00:00:00", "2020-08-22T00:00:00", "2020-08-22T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-24T00:00:00", "2020-08-27T00:00:00", "2020-08-27T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-28T00:00:00", "2020-08-28T00:00:00", "2020-08-29T00:00:00", "2020-08-29T00:00:00", "2020-08-29T00:00:00", "2020-08-31T00:00:00", "2020-08-31T00:00:00", "2020-08-31T00:00:00", "2020-09-07T00:00:00", "2020-09-07T00:00:00", "2020-09-07T00:00:00", "2020-09-08T00:00:00", "2020-09-08T00:00:00", "2020-09-08T00:00:00"], "xaxis": "x", "y": [3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3.700000047683716, 3 ...

# %%
df['Day'].unique()
# Out:
# array(['2019 09 11', '2019 09 12', '2019 09 13', '2019 09 14',
#        '2019 09 17', '2020 08 22', '2020 08 24', '2020 08 27',
#        '2020 08 28', '2020 08 29', '2020 08 31', '2020 09 07',
#        '2020 09 08'], dtype=object)

# %%
configure_plotly_browser_state()
def line_chart(process_select):
    fig_all=[]
    for process_name in process_select:
      df_dict=final_data[process_name] # process name
      i=1
      #Layout
      fig = make_subplots(          # Dim name
          rows=len(df_dict), cols=1,
          #shared_xaxes=True, # share same axis
          #vertical_spacing=0.05, # adjust spacing between charts
          #column_widths=[0.8, 0.2],
          subplot_titles=list(df_dict.keys()) # dict with key is process name and value is list of dim (contain name, cp, cpk...)
      )
      for name in list(df_dict.keys()): #also group
        df=df_dict[name].copy()
        df=df.sort_values(by=['Date'])
        for a in df.columns[1:]:
          df[a] = df[a].round(decimals=3)
        df=df.reset_index(drop=True)
        # Draw control chart
        df_group=df.groupby('Date').mean()
        #df=df.set_index('Date')
        #if start_date != '':
        #  df=df[start_date:end_date]
        #Control chart 1 
        fig.append_trace(go.Scatter(
                                x=df_group.index, y=df_group['Value'],mode='lines+markers',
                                name='mean ', 
                                line=dict( color='#4280F5')
                                ),row=i, col=1)
        #USL, LSL
        fig.append_trace(go.Scatter(x=df_group.index, y=df_group['USL'],name='USL ', line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
        fig.append_trace(go.Scatter(x=df_group.index, y=df_group['LSL'],name='LSL ',line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['Nominal'],name='Nominal ',line=dict( color='#FF5733'),mode='lines'),row=i, col=1)
        # UCL, LCL
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['UCL'],name='UCL ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['LCL'],name='LCL ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
        #fig.append_trace(go.Scatter(x=df_group.index, y=df_group['Mean'],name='Mean ', line=dict( color='#33C2FF'),mode='lines'),row=i, col=1)
        i=i+1

      if len(df_dict)>1:
        fig.update_layout(height=200*len(df_dict), width=1200, title_text='Process: '+process_name)
      else:
        fig.update_layout(height=300, width=1200, title_text='Process: '+process_name)
      #fig update each process (contain a lot of dim inside)
      #fig.show()
      fig_all.append(fig)  
    return fig_all # fig nay chi la 1 process cuoi cung thoi, lam sao return toan bo fig ?

fig_all=line_chart(process_select)    
for fig in fig_all:
    fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="6310b9ce-5ad1-4840-a7e4-bd3dad9b8407" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6310b9ce-5ad1-4840-a7e4-bd3dad9b8407")) {
#                     Plotly.newPlot(
#                         '6310b9ce-5ad1-4840-a7e4-bd3dad9b8407',
#                         [{"line": {"color": "#4280F5"}, "mode": "lines+markers", "name": "mean ", "type": "scatter", "x": ["2019-09-07T00:00:00", "2019-09-07T08:00:00", "2019-09-09T08:00:00", "2019-09-11T11:00:00", "2019-09-12T08:00:00", "2019-09-12T09:00:00", "2019-09-17T08:00:00", "2019-09-17T16:00:00", "2019-09-19T16:00:00", "2019-09-20T00:00:00", "2019-09-20T08:00:00", "2020-08-21T16:00:00", "2020-08-22T08:00:00", "2020-08-22T17:00:00", "2020-08-24T12:00:00", "2020-08-25T17:00:00", "2020-08-26T09:00:00", "2020-08-26T16:00:00", "2020-08-27T08:00:00", "2020-08-27T19:00:00", "2020-08-28T10:00:00", "2020-08-28T16:00:00", "2020-08-29T12:00:00", "2020-08-29T15:00:00", "2020-08-31T08:00:00", "2020-08-31T16:00:00", "2020-09-01T16:00:00", "2020-09-03T08:00:00", "2020-09-03T17:00:00", "2020-09-04T09:00:00", "2020-09-04T16:00:00", "2020-09-05T08:00:00", "2020-09-07T09:00:00", "2020-09-08T10:00:00", "2020-09-08T16:00:00", "2020-09-11T17:00:00", "2020-09-12T16:00:00", "2020-09-14T09:00:00", "2020-09-14T16:00:00", "2020-09-15T09:00:00", "2020-09-15T15:00:00", "2020-09-16T08:00:00", "2020-09-17T08:00:00", "2020-09-17T17:00:00", "2020-09-18T08:00:00"], "xaxis": "x", "y": [0.2356666624546051, 0.2313999980688095, 0.2173333317041397, 0.22733333706855774, 0.23600000143051147, 0.2280000001192093, 0.2329999953508377, 0.23340000212192535, 0.23260000348091125, 0.22300000488758087, 0.2433333396911621, 0.23960000276565552, 0.23960000276565552, 0.24239999055862427, 0.23659999668598175, 0.23759999871253967, 0.24040000140666962, 0.2362000048160553, 0.23399999737739563, 0.2240000069141388, 0.23666666448116302, 0.2396666705608368, 0.22499999403953552, 0.24133333563804626, 0.23800000548362732, 0.2329999953508377, 0.24033333361148834, 0.22966666519641876, 0.2290000021457672, 0.23633334040641785, 0.23000000417232513, 0.24133333563804626, 0.23266665637493134, 0.23399999737739563, 0.23133333027362823, 0.23600000143051147, 0.23333333432674408, 0.21899999678134918, 0.22566667199134827, 0.23899999260902405, 0.23333333432674408, 0.23633334040641785, 0.2409999966621399, 0.23333333432674408, 0.24266666173934937], "yaxis": "y"}, {"line": {"color": "#FF5733"}, "mode": "lines", "name": "USL ", "type": "scatter", "x": ["2019-09-07T00:00:00", "2019-09-07T08:00:00", "2019-09-09T08:00:00", "2019-09-11T11:00:00", "2019-09-12T08:00:00", "2019-09-12T09:00:00", "2019-09-17T08:00:00", "2019-09-17T16:00:00", "2019-09-19T16:00:00", "2019-09-20T00:00:00", "2019-09-20T08:00:00", "2020-08-21T16:00:00", "2020-08-22T08:00:00", "2020-08-22T17:00:00", "2020-08-24T12:00:00", "2020-08-25T17:00:00", "2020-08-26T09:00:00", "2020-08-26T16:00:00", "2020-08-27T08:00:00", "2020-08-27T19:00:00", "2020-08-28T10:00:00", "2020-08-28T16:00:00", "2020-08-29T12:00:00", "2020-08-29T15:00:00", "2020-08-31T08:00:00", "2020-08-31T16:00:00", "2020-09-01T16:00:00", "2020-09-03T08:00:00", "2020-09-03T17:00:00", "2020-09-04T09:00:00", "2020-09-04T16:00:00", "2020-09-05T08:00:00", "2020-09-07T09:00:00", "2020-09-08T10:00:00", "2020-09-08T16:00:00", "2020-09-11T17:00:00", "2020-09-12T16:00:00", "2020-09-14T09:00:00", "2020-09-14T16:00:00", "2020-09-15T09:00:00", "2020-09-15T15:00:00", "2020-09-16T08:00:00", "2020-09-17T08:00:00", "2020-09-17T17:00:00", "2020-09-18T08:00:00"], "xaxis": "x", "y": [0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25], "yaxis": "y"}, {"line": {"color": "#FF5733"}, "mode": "lines", "name": "LSL ", "type": "scatter", "x": ["2019-09-07T00:00:00", "2019-09-07T08:00:00", "2019-09-09T08:00:00", "2019-09-11T11:00:00", "2019-09-12T08:00:00", "2019-09-12T09:00:00", "2019-09-17T08:00:00", "2019-09-17T16:00:00", "2019-09-19T16:00:00", "2019-09-20T00:00:00", "2019-09-20T08:00:00", "2020-08-21T16:00:00", "2020-08-22T08:00:00", "2020-08-22T17:00:00", "2020-08-24T12:00:00", "2020-0 ...

# %%
# importing "copy" for copy operations 
import copy 
  
# initializing list 1 
li1 = [1, 2, [3,5], 4] 
  
# using copy to shallow copy  
li2 = copy.copy(li1) 
  
# original elements of list 
print ("The original elements before shallow copying") 
for i in range(0,len(li1)): 
    print (li1[i],end=" ") 
  
print("\r") 
  
# adding and element to new list 
li2[2][0] = 7
  
# checking if change is reflected 
print ("li2") 
for i in range(0,len( li2)): 
    print (li2[i],end=" ") 
print ("\nli1") 
for i in range(0,len( li1)): 
    print (li1[i],end=" ")
# Out:
# The original elements before shallow copying
# 1 2 [3, 5] 4
# li2
# 1 2 [7, 5] 4
# li1
# 1 2 [7, 5] 4

# %%
# importing "copy" for copy operations 
import copy 
  
# initializing list 1 
li1 = [1, 2, [3,5], 4] 
  
# using copy to shallow copy  
li2 = copy.deepcopy(li1) 
  
# original elements of list 
print ("The original elements before shallow copying") 
for i in range(0,len(li1)): 
    print (li1[i],end=" ") 
  
print("\r") 
  
# adding and element to new list 
li2[2][0] = 7
  
# checking if change is reflected 
print ("li2") 
for i in range(0,len( li2)): 
    print (li2[i],end=" ") 
print ("\nli1") 
for i in range(0,len( li1)): 
    print (li1[i],end=" ")
# Out:
# The original elements before shallow copying
# 1 2 [3, 5] 4
# li2
# 1 2 [7, 5] 4
# li1
# 1 2 [3, 5] 4
